# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
df = pd.read_csv("./pokemon-images-and-types/pokemon.csv")
df1 = pd.read_csv("./pokemon/pokemon_alopez247.csv")

# %%
names = df.iloc[:,0]
names = [name.lower() for name in names]

# %%
names1 = df1.iloc[:,1].values
names1 = [name.lower() for name in names1]

# %%
df.iloc[:, 0] = names
df1.iloc[:, 1] = names1

# %%
dff = pd.merge(df, df1, how='inner', on='Name')

# %%
dff.head()
# Out:
#          Name  Type1   Type2  Number Type_1  Type_2  Total  HP  Attack  \
# 0   bulbasaur  Grass  Poison       1  Grass  Poison    318  45      49
# 1     ivysaur  Grass  Poison       2  Grass  Poison    405  60      62
# 2    venusaur  Grass  Poison       3  Grass  Poison    525  80      82
# 3  charmander   Fire     NaN       4   Fire     NaN    309  39      52
# 4  charmeleon   Fire     NaN       5   Fire     NaN    405  58      64
#
#    Defense       ...        Color  hasGender  Pr_Male  Egg_Group_1  \
# 0       49       ...        Green       True    0.875      Monster
# 1       63       ...        Green       True    0.875      Monster
# 2       83       ...        Green       True    0.875      Monster
# 3       43       ...          Red       True    0.875      Monster
# 4       58       ...          Red       True    0.875      Monster
#
#    Egg_Group_2 hasMegaEvolution  Height_m  Weight_kg Catch_Rate  \
# 0        Grass            False      0.71        6.9         45
# ...

# %%
mdf = dff.drop(['Type_1','Type_2'], axis=1)

# %%
mdf.to_csv('pokemon.csv')

# %%
mdf.to_json('pokemon.json')
